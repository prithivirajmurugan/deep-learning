# %% [markdown]
# <a href="https://colab.research.google.com/github/prithivirajmurugan/deep-learning/blob/main/Engine_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Engine Basics

# %% [markdown]
# Reciprocating internal combustion engines - subclass of heat engines
#
#
# 1.   Spark-ignited (SI)
# 2.   Compression-ignited (CI)
#
# Possible engine classification:
# 1. Based on engine mobility
# 2. application
# 3. Fuel
# 4. configuration etc

# %% [markdown]
# Heat Engines -> Chemical energy in a fuel into work by combustion which is used to raised the temperature of working fuild (air or steam) which is used to do work
#
# Based on combustion - classification
# 1. Internal Combustion engines
# 2. External Combustion engines
#
# Can be either reciprocating or rotatory in motion - working fluid moves the piston in up and down motion
#
# Rotatory motion - the working fluid spins a rotor.

# %% [markdown]
# ##Heat Engine
#
# A Heat engine is a system which converts heat into work by taking heat from the hot body to carry out from some work
#
# ![image.png](data:image/png;base64,...)
#
# ImgSrc : Patel V.K., Savsani V.J., Tawhid M.A. (2019) Thermal Design and Optimization of Heat Engines and Heat Pumps. In: Thermal System Optimization. Springer, Cham. https://doi.org/10.1007/978-3-030-10477-1_4
#
# Heat engine works not based on the temperature but based on the temperature difference, this is because like to spread out in space and attain thermal equilibrium
#
# Full cycle of heat engine involves
# 1. Addition of heat $Q_H$
# 2.Part of $Q_H$ is used to perform work $W$.
# 3.Rest of heat energy is removed by cold temperature $Q_C$
#
# $Q_H = W + Q_C$
#
# ## Carnot engine
#
# Ideal reversible heat engine
#
# $e = 1- T_C/T_H$
# ## Efficiency of heat engine:
# $e = work done / input heat = W / Q_H = 1 - Q_C/Q_H$
#
# ## Thermo-dynamic systems
#
# **Isolated system** - no transfer of energy and mass with surroundings
#
# **Closed system** - transfers energy but no transfer of mass
#
# **Open system** - mass and energy both are transmitted
#
# ## Thermodynamic process
#
# * **Adiabatic process** - No heat transfer into or out of the system occurs
# * **Isochoric process** - No chnage in volume occurs
# * **Isobaric process** - No change in pressure occurs
# * **Isothermal process** - No change in temperature occurs
#
# **First three laws of thermodynamics**
#
# 1. Energy can be converted from one form to another with the interaction of heat, work and internal energy, but it cannot be created nor destroyed, under any circumstances.
#
# 2. The Second Law of Thermodynamics states that the state of entropy of the entire universe, as an isolated system, will always increase over time. The second law also states that the changes in the entropy in the universe can never be negative.
#
# 3. Third laws of thermodynamics roughly states that entropy becomes constant as the temperature reaches absolute zero.
#
#
# **PV Diagram:**
#
#
# ![image.png](data:image/png;base64,...)
#
# **1-2**.The working fluid absorbs heat energy from the source and expands, this expansion does work to the surroundings, during this process the temperature of the working fluid will remain the same , hence this is called as Iso-thermal expansion
#
# **2-3**.In this stage, the working fluid continues to do some work and there by losing some of its internal energy, here the temperature of working fluid reduces but the entrophy remains constant and hence this stage is called adiabatic expansion process
#
# **3-4**. In this stage, the working fluid undergoes compression by losing heat to the cold reservoir in a constant temperature and hence it is called as isothermal compression

# %% [markdown]
# # External Combustion Engine
#
# Working fluid is seperated from fuel-air mixture -- heat exchange between working fluid and the combustion
#
# Example : Steam Engine and Sterling engine

# %% [markdown]
# # Internal Combustion Engines
#
# Working fluid - Air
#
# Fuel - Liquid fuels such as gasoline and diesel or gaseous fuel such as natural gas and LPG
#
# **Two sub categories**
#  1. Two stroke
#  2. Four stroke engines
#
# **Common Goals of design of engine:**
#  1. Maximizing the power output
#  2. Minimizing the engine consumtion
#  3. Reducing pollutants
#
# **Based on ignition** - both two and four stroke engines can be classified as:
#  1. Spark-ignited
#  2.Compression-ignited
#
#  **Spark-ignited** - relatively homogenous mixture of pre-mixed fuel-air mixture , propagation of flame from the spark, kinetically controlled process
#
#  **Combustion-ignited** - fuel injected approximately at the time ignition is required - heterogenous mixture - combustion is not controlled and can happen at many points, the fuel is injection at the point when the air is compressed, upon injection the fuel reaches the auto-ignition temperature and ignites spontaneously

# %% [markdown]
# ## Four-Stroke Cycle Engine
#
# Takes four strokes to complete the combustion cycle
#
# 1. Intake stroke
# 2. Compression stroke
# 3. Power stroke
# 4. Exhaust stroke
#
# ![image.png](data:image/png;base64,...)
#
# ## Operation:
#
# **Intake stroke** : Piston move from Top-Dead-Centre toward Bottom-Dead-Centre, which increases the volume of the cylinder,creating a low-pressure and the outside air or air/fuel mixture is pulled in the cylinder.
#
# **Compression stroke** : The piston moving from its position of TDC to the BDC of the cylinder, which compresses the air inside the cylinder, decrease in the volume increases the cyclinder pressure, which causes the increase the temperature of the working fluid
#
# **Power stroke** : with the increase of temperature in working fluid, fuel is injected and ignited, which inturns generates heat and causes the working fluid to expand creating a high pressure, pushing the piston towards TDC, this is called as Expansion Stroke or Power stroke as this stroke generates the over-all power output
#
# **Exhaust stroke** - At the end of the Power stroke, the piston returns back to the BDC from the TDC, which pushes the exhaust gases (combustion byproduct), outside of the cylinder and becomes ready for the next cycle.
#
# ![image.png](data:image/png;base64,...)
#
# **Point 1** - intake valve opens
#
# **Point 2** - intake valve closes
#
# **Point 3** - exahaust valve opens
#
# **Point 4** - exhaust valve closing
#
# **Point 1 - 2** : Intake stroke - filling of air with atmospheric pressue
#
# **Point 2 - 3** : Compression and Expansion Stroke
#
# **Point 3 - 4** : Exhaust stroke
#
# **Between point 1 and 4**, the intake and exhaust valve remains open and is used of engine performance

# %% [markdown]
# ## Two-Stroke Cycle Engine
#
# 1. Compression Stroke
# 2. Power Stroke
#
# ![image.png](data:image/png;base64,...)
#
# Exhaust and intake occurs simultaneously
#
# 1.**Compression stroke**: The inlet port opens, the air-fuel mixture enters the chamber and the piston moves upwards compressing this mixture. A spark plug ignites the compressed fuel and begins the power stroke.
#
#
# 2.**Power stroke**: The heated gas exerts high pressure on the piston, the piston moves downward (expansion), waste heat is exhausted.

# %% [markdown]
# ## Different Configuration of Engines
#
#
#
# *   Inline engine
# *   Vee Engine
#
# ![image.png](data:image/png;base64,...)
#
# Some other configuration
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Parameters of engine
#
# $B_{cyl}$ -- Bore of Cylinder - the diameter of the cyliner
#
# $S_p$ -- Piston Stroke -- Length travesed by the piston head in the cylinder in a stroke
#
# # Swept Volume:
#
# Product of the cross-section area of that cylinder and piston stroke
#
# $V_s = (\pi*B_{cyl}^2 /4)*S_p$
#
# # Clearance Volume
#
# The volume above the piston when it is at its TDC
#
# ![image.png](data:image/png;base64,...)
#
# # Compression Ratio:
#
# Volumetric compression ratio is the ratio of the total (maximum) to minimum cyclinder volume
#
# $ C_r = Maximum Cylinder Volume / Minimum Cylinder Volume $
#
# $ C_r = (V_c + V_s) / V_c $
#
# Not the effective or trapped compression ratio since compression is non-exist until all valves and ports are closed
#
# # Thermal efficiency
#
# Ratio between the useful work done by the engine to the thermal energy supplied to it.
#
# $\eta_{th} = Work Output / Thermal Energy Supplied to the Control Volume $
#
# $\eta_{th}$ is cannot be equal to 100% as the convertion of thermal energy to work will include energy losses
#
# ![image.png](data:image/png;base64,...)
#
#
# Brake thermal efficiency - ratio of the work - friction losses and the pumping work to the heat injected
#
# Indicated Thermal efficiency - ratio of work + friction and pumping losses to the heat injected.

# %% [markdown]
# # Engine Performance Parameters
#
# ## Power Output
#
# Maximum torque at the given engine speed
#
# $ Power Output = T*N / Constant $
#
# Power is the rate at which the work is supplied
#
# The Power is usually measured using a dynamo-meter
#
# $ T = F * r $
#
# Work done for one revolution
#
# $ Work = 2 * \pi * r * F $
#
# $ Work = 2 * \pi * T $
#
# Work done per unit time
#
# $ Work = 2 * \pi * T * N $
#
# Work done per minute = Power
#
# $ Power = 2 * \pi * T * N $

# %% [markdown]
# ## Indicated Power
#
# Brake power is the power output result of the application of engine to a load where as indicated power is the power as the result of the gas compression and expansion action in the cylinder
#
# $ Indicated Power = Brake Power + Pumping Power + Friction Power $

# %% [markdown]
# ## Indicated Mean Effective Pressure
#
# ![image.png](data:image/png;base64,...)
#
# Area A indicates the work exerted by the working fluid on the surface of the piston
#
# Indicated Mean Effective pressure is the work exerted by the gas on the piston per swept volume
#
# $imep = \int P_i/V_d . dV $

# %% [markdown]
# ## Break Mean Effective Pressure
#
# Portion of the bulk pressure exerted on the surface of the piston ($ imep $), that produces useful power
#
# It represents the net work after subtracting friction, pumping, and other parasitic losses (the largest of
# these losses being that of friction)
#
#
# $bmep = \int P_b/V_d . dV $

# %% [markdown]
# ## Specific Fuel Consumption
#
# How much fuel the engine consumes in the process of producing an output of one horsepower or kilowatt
#
# $ bsfc = Fuel Consumption per Unit Time / Brake Power Output $
#
# $ isfc = Fuel Consumption per Unit Time / indicated Power Output $
#
# Engine Specific Volume
#
# $ Specific Volume = Engine Volume / Rated Power $
#
# $ Specific Weight = Engine Weight / Rated Power $

# %% [markdown]
# ## Volumetric efficiency
#
# Ratio of volume of gas/air drawn during the suction stroke to the total displacement of the all cylinder at the atmospheric pressure
#
# I measure the engine efficiency in suction of air during the intake stroke , For Naturally aspirated engine it is 80% maximum while the force-induction engine ( Turbo-charged or super-turbocharged ) might have more than 100% efficiency.
#
# This is different from Mechanical efficiency since this measure the engine's efficiency at output accounting all the loss due to friction, heat loss etc...

# %% [markdown]
# References
#
# https://dieselnet.com/tech/diesel_fundamentals.php
#
# https://dieselnet.com/tech/engine_efficiency.php
